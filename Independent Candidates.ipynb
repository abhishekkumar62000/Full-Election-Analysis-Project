# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

ind=pd.DataFrame(columns=['CANDIDATE', '%', 'CONSTITUENCY', 'PARTY', 'STATE', 'YEAR'])

# %%
#1989
df=pd.read_csv('1989.csv')
y1=df[['CANDIDATE', '%', 'CONSTITUENCY', 'PARTY', 'TERRITORY']]
y1.sort_values(['%', 'CONSTITUENCY'], ascending=[False, True])

unique=list(y1.CONSTITUENCY.unique())
check=[]

for i in y1.index:
    const=y1['CONSTITUENCY'][i]
    if(const in unique and const not in check):
        check.append(const)
        ind=ind.append({'CANDIDATE': y1['CANDIDATE'][i], '%': y1['%'][i], 'CONSTITUENCY': y1['CONSTITUENCY'][i], 'PARTY': y1['PARTY'][i], 'STATE': y1['TERRITORY'][i], 'YEAR': '1989'}, ignore_index=True)
        
    elif(const in unique and const in check):
        continue

# %%
#1991        
df=pd.read_csv('1991.csv')
y1=df[['CANDIDATE', '%', 'CONSTITUENCY', 'PARTY', 'TERRITORY']]
y1.sort_values(['%', 'CONSTITUENCY'], ascending=[False, True])

unique=list(y1.CONSTITUENCY.unique())
check=[]

for i in y1.index:
    const=y1['CONSTITUENCY'][i]
    if(const in unique and const not in check):
        check.append(const)
        ind=ind.append({'CANDIDATE': y1['CANDIDATE'][i], '%': y1['%'][i], 'CONSTITUENCY': y1['CONSTITUENCY'][i], 'PARTY': y1['PARTY'][i], 'STATE': y1['TERRITORY'][i], 'YEAR': '1991'}, ignore_index=True)
        
    elif(const in unique and const in check):
        continue

# %%
#1996
df=pd.read_csv('1996.csv')
y1=df[['CANDIDATE', '%', 'CONSTITUENCY', 'PARTY', 'TERRITORY']]
y1.sort_values(['%', 'CONSTITUENCY'], ascending=[False, True])

unique=list(y1.CONSTITUENCY.unique())
check=[]

for i in y1.index:
    const=y1['CONSTITUENCY'][i]
    if(const in unique and const not in check):
        check.append(const)
        ind=ind.append({'CANDIDATE': y1['CANDIDATE'][i], '%': y1['%'][i], 'CONSTITUENCY': y1['CONSTITUENCY'][i], 'PARTY': y1['PARTY'][i], 'STATE': y1['TERRITORY'][i], 'YEAR': '1996'}, ignore_index=True)
        
    elif(const in unique and const in check):
        continue

# %%
#1998        
df=pd.read_csv('1998.csv')
y1=df[['CANDIDATE', '%', 'CONSTITUENCY', 'PARTY', 'TERRITORY']]
y1.sort_values(['%', 'CONSTITUENCY'], ascending=[False, True])

unique=list(y1.CONSTITUENCY.unique())
check=[]

for i in y1.index:
    const=y1['CONSTITUENCY'][i]
    if(const in unique and const not in check):
        check.append(const)
        ind=ind.append({'CANDIDATE': y1['CANDIDATE'][i], '%': y1['%'][i], 'CONSTITUENCY': y1['CONSTITUENCY'][i], 'PARTY': y1['PARTY'][i], 'STATE': y1['TERRITORY'][i], 'YEAR': '1998'}, ignore_index=True)
        
    elif(const in unique and const in check):
        continue

# %%
#1999
df=pd.read_csv('1999.csv')
y1=df[['CANDIDATE', '%', 'CONSTITUENCY', 'PARTY', 'TERRITORY']]
y1.sort_values(['%', 'CONSTITUENCY'], ascending=[False, True])

unique=list(y1.CONSTITUENCY.unique())
check=[]

for i in y1.index:
    const=y1['CONSTITUENCY'][i]
    if(const in unique and const not in check):
        check.append(const)
        ind=ind.append({'CANDIDATE': y1['CANDIDATE'][i], '%': y1['%'][i], 'CONSTITUENCY': y1['CONSTITUENCY'][i], 'PARTY': y1['PARTY'][i], 'STATE': y1['TERRITORY'][i], 'YEAR': '1999'}, ignore_index=True)
        
    elif(const in unique and const in check):
        continue

# %%
#2004        
df=pd.read_csv('2004.csv')
y1=df[['CANDIDATES', '% OF TOTAL VOTES', 'CONSTITUENCY', 'PARTY', 'TERRITORY']]
y1.sort_values(['% OF TOTAL VOTES', 'CONSTITUENCY'], ascending=[False, True])

unique=list(y1.CONSTITUENCY.unique())
check=[]

for i in y1.index:
    const=y1['CONSTITUENCY'][i]
    if(const in unique and const not in check):
        check.append(const)
        ind=ind.append({'CANDIDATE': y1['CANDIDATES'][i], '%': y1['% OF TOTAL VOTES'][i], 'CONSTITUENCY': y1['CONSTITUENCY'][i], 'PARTY': y1['PARTY'][i], 'STATE': y1['TERRITORY'][i], 'YEAR': '2004'}, ignore_index=True)
        
    elif(const in unique and const in check):
        continue

# %%
ind=ind[ind['PARTY']=='IND']
ind.reset_index(drop=True, inplace=True)
display(ind)
# Out:
#                           CANDIDATE          %               CONSTITUENCY  \
# 0                      MOHD. HASSAN  52.650000                     LADAKH
# 1                    KANKAR MUNJARE  34.250000                   BALAGHAT
# 2                  VAMANRAO MAHADIK  35.910000       BOMBAY SOUTH CENTRAL
# 3           DESHMUKH ASHOK ANANDRAO  44.210000                   PARBHANI
# 4                      KIRPAL SINGH  47.030000                   AMRITSAR
# 5                  ATINDERPAL SINGH  46.590000                    PATIALA
# 6                       DHIAN SINGH  30.880000                  FEROZEPUR
# 7    FASIURAAHMANALIYAS MUNNAN KHAN  34.970000                  BALRAMPUR
# 8                           JAGDISH  40.150000                   GHAZIPUR
# 9        DELKAR MOHANBHAI SANJIBHAI  42.660000  DADRA & NAGAR HAVELI (ST)
# 10            TANDEL DEVJI JOGIBHAI  42.820000              DAMAN AND DIU
# 11  SATYENDRA NATH BROHMO CHOUDHURY  53.200000             KOKRAJHAR (ST)
# 12                        TOMO RIBA  53.250000             ARUNACHAL WEST
# 13                 WANGCHA RAJKUMAR  33.730000             ARUNACHAL EAST
# 14                     LOUIS ISLARY  24.360000             KOKRAJHAR (ST)
# 15                   RAMENDRA KUMAR  42.890000                  BEGUSARAI
# 16                     ARVIND KUMAR  33.070000                    SONEPAT
# 17                  XAVIER ARRAKKAL  46.910000                  ERNAKULAM
# 18                   MAHENDRA KARMA  32.150000                BASTAR (ST)
# 19                  G.GILBERT SWELL  56.180000                   SHILLONG
# 20                    KALAPNATH RAI  32.620000                      GHOSI
# 21   SANSUMA KHUNGGUR BWISWMUTHIARY  25.550000             KOKRAJHAR (ST)
# 22              DR. H. LALLUNGMUANA  34.870000               MIZORAM (ST)
# 23              SATNAM SINGH KAINTH  52.040000              PHILLAUR (SC)
# 24                       BUTA SINGH  54.320000                JALORE (SC)
# 25                    RAMAMURTHY K.  55.470000                      SALEM
# 26                    MANEKA GANDHI  55.990000                   PILIBHIT
# 27    SANSUMA KHUNGGUR BWISMUTHIARY  37.570000             KOKRAJHAR (ST)
# 28                    RAJESH RANJAN  63.170000                     PURNEA
# 29            ATHAWALE RAMDAS BANDU  52.910000            PANDHARPUR (SC)
# 30                      VANLALZAWMA  58.800000               MIZORAM (ST)
# 31                    MANEKA GANDHI  57.940000                   PILIBHIT
# 32       DELKAR MOHANBHAI SANJIBHAI  41.520000  DADRA & NAGAR HAVELI (ST)
# 33   SANSUMA KHUNGGUR BWISWMUTHIARY  56.686392             KOKRAJHAR (ST)
# 34                THUPSTAN CHHEWANG  38.026831                     LADAKH
# 35                DR SEBASTIAN PAUL  30.215381                  ERNAKULAM
# 36                  MANI CHARENAMEI  28.856033         OUTER MANIPUR (ST)
# 37                    HARISH NAGPAL  21.416255                     AMROHA
#
#    PARTY                 STATE  YEAR
# 0    IND       JAMMU & KASHMIR  1989
# 1    IND        MADHYA PRADESH  1989
# 2    IND           MAHARASHTRA  1989
# 3    IND           MAHARASHTRA  1989
# 4    IND                PUNJAB  1989
# 5    IND                PUNJAB  1989
# 6    IND                PUNJAB  1989
# 7    IND         UTTAR PRADESH  1989
# 8    IND         UTTAR PRADESH  1989
# 9    IND  DADRA & NAGAR HAVELI  1989
# 10   IND           DAMAN & DIU  1989
# 11   IND                 ASSAM  1991
# 12   IND     ARUNACHAL PRADESH  1996
# 13   IND     ARUNACHAL PRADESH  1996
# 14   IND                 ASSAM  1996
# 15   IND                 BIHAR  1996
# 16   IND               HARYANA  1996
# 17   IND                KERALA  1996
# 18   IND        MADHYA PRADESH  1996
# 19   IND             MEGHALAYA  1996
# 20   IND         UTTAR PRADESH  1996
# 21   IND                 ASSAM  1998
# 22   IND               MIZORAM  1998
# 23   IND                PUNJAB  1998
# 24   IND             RAJASTHAN  1998
# 25   IND            TAMIL NADU  1998
# 26   IND         UTTAR PRADESH  1998
# 27   IND                 ASSAM  1999
# 28   IND                 BIHAR  1999
# 29   IND           MAHARASHTRA  1999
# 30   IND               MIZORAM  1999
# 31   IND         UTTAR PRADESH  1999
# 32   IND  DADRA & NAGAR HAVELI  1999
# 33   IND                 ASSAM  2004
# 34   IND       JAMMU & KASHMIR  2004
# 35   IND                KERALA  2004
# 36   IND               MANIPUR  2004
# 37   IND         UTTAR PRADESH  2004

# %%
#SC reserved constituencies with independent candidates as winners
ind[ind['CONSTITUENCY'].str.contains("\(SC\)")]
# Out:
#                 CANDIDATE      %     CONSTITUENCY PARTY        STATE  YEAR
# 23    SATNAM SINGH KAINTH  52.04    PHILLAUR (SC)   IND       PUNJAB  1998
# 24             BUTA SINGH  54.32      JALORE (SC)   IND    RAJASTHAN  1998
# 29  ATHAWALE RAMDAS BANDU  52.91  PANDHARPUR (SC)   IND  MAHARASHTRA  1999

# %%
#ST reserved constituencies with independent candidates as winners
ind[ind['CONSTITUENCY'].str.contains("\(ST\)")]
# Out:
#                           CANDIDATE          %               CONSTITUENCY  \
# 9        DELKAR MOHANBHAI SANJIBHAI  42.660000  DADRA & NAGAR HAVELI (ST)
# 11  SATYENDRA NATH BROHMO CHOUDHURY  53.200000             KOKRAJHAR (ST)
# 14                     LOUIS ISLARY  24.360000             KOKRAJHAR (ST)
# 18                   MAHENDRA KARMA  32.150000                BASTAR (ST)
# 21   SANSUMA KHUNGGUR BWISWMUTHIARY  25.550000             KOKRAJHAR (ST)
# 22              DR. H. LALLUNGMUANA  34.870000               MIZORAM (ST)
# 27    SANSUMA KHUNGGUR BWISMUTHIARY  37.570000             KOKRAJHAR (ST)
# 30                      VANLALZAWMA  58.800000               MIZORAM (ST)
# 32       DELKAR MOHANBHAI SANJIBHAI  41.520000  DADRA & NAGAR HAVELI (ST)
# 33   SANSUMA KHUNGGUR BWISWMUTHIARY  56.686392             KOKRAJHAR (ST)
# 36                  MANI CHARENAMEI  28.856033         OUTER MANIPUR (ST)
#
#    PARTY                 STATE  YEAR
# 9    IND  DADRA & NAGAR HAVELI  1989
# 11   IND                 ASSAM  1991
# 14   IND                 ASSAM  1996
# 18   IND        MADHYA PRADESH  1996
# 21   IND                 ASSAM  1998
# 22   IND               MIZORAM  1998
# 27   IND                 ASSAM  1999
# 30   IND               MIZORAM  1999
# 32   IND  DADRA & NAGAR HAVELI  1999
# 33   IND                 ASSAM  2004
# 36   IND               MANIPUR  2004

# %%
ind['CONSTITUENCY'].value_counts()
# Out:
# KOKRAJHAR (ST)               5
# LADAKH                       2
# PILIBHIT                     2
# ERNAKULAM                    2
# MIZORAM (ST)                 2
# DADRA & NAGAR HAVELI (ST)    2
# BALAGHAT                     1
# PANDHARPUR (SC)              1
# PATIALA                      1
# FEROZEPUR                    1
# BEGUSARAI                    1
# BOMBAY SOUTH CENTRAL         1
# AMRITSAR                     1
# ARUNACHAL WEST               1
# SHILLONG                     1
# SALEM                        1
# PURNEA                       1
# AMROHA                       1
# OUTER MANIPUR (ST)           1
# GHAZIPUR                     1
# GHOSI                        1
# BASTAR (ST)                  1
# DAMAN AND DIU                1
# PARBHANI                     1
# PHILLAUR (SC)                1
# JALORE (SC)                  1
# BALRAMPUR                    1
# ARUNACHAL EAST               1
# SONEPAT                      1
# Name: CONSTITUENCY, dtype: int64

# %%
plt.figure(figsize=(16,9))
ind['CONSTITUENCY'].value_counts().sort_index().plot.bar()
plt.title("Constituencies with the most number of Winning Independent candidates")
plt.xlabel("Constituencies")
plt.ylabel("No. of Winning Independent candidates")
plt.show()

# %%
ind['STATE'].value_counts()
# Out:
# UTTAR PRADESH           6
# ASSAM                   5
# PUNJAB                  4
# MAHARASHTRA             3
# MIZORAM                 2
# MADHYA PRADESH          2
# ARUNACHAL PRADESH       2
# BIHAR                   2
# KERALA                  2
# DADRA & NAGAR HAVELI    2
# JAMMU & KASHMIR         2
# MANIPUR                 1
# HARYANA                 1
# RAJASTHAN               1
# TAMIL NADU              1
# MEGHALAYA               1
# DAMAN & DIU             1
# Name: STATE, dtype: int64

# %%
plt.figure(figsize=(16,9))
ind['STATE'].value_counts().sort_index().plot.bar()
plt.title("States with the most number of Winning Independent candidates")
plt.xlabel("States")
plt.ylabel("No. of Winning Independent candidates")

plt.show()

# %%
ind['YEAR'].value_counts()
# Out:
# 1989    11
# 1996     9
# 1998     6
# 1999     6
# 2004     5
# 1991     1
# Name: YEAR, dtype: int64

# %%
plt.figure(figsize=(16,9))
ind['YEAR'].value_counts().sort_index().plot.bar()
plt.title("Year-wise most number of Winning Independent candidates")
plt.xlabel("Years")
plt.ylabel("No. of Winning Independent candidates")
plt.show()
